# %% [markdown]
# ## Data Precproccessing Technique 01
#
# # One Hot encoing
#
#   ![image.png](attachment:0a246c2d-c591-4687-a5a6-b628a610ebc6.png)
#
# - problem is model will think like this if we get 2.6 like that show we can not use that one
# - in here we will use the  One Hot Encoing
#
#   ![image.png](attachment:946b550d-dd86-4e05-be44-1a99dfdd4ca2.png)

# %%
import pandas as pd

# %%
data =  pd.read_csv('student.csv')

# %%
data
# Out:
#    Age  Result
# 0   18    Pass
# 1   20    Fail
# 2   19  Absent
# 3   21    Pass

# %%
data["Result"]
# Out:
# 0      Pass
# 1      Fail
# 2    Absent
# 3      Pass
# Name: Result, dtype: object

# %%
result_category = data['Result']

# %%
from sklearn.preprocessing import LabelEncoder
obj = LabelEncoder()
result = obj.fit_transform(result_category)

# %%
result    # the output like this 2 is thinking that 1 is near to 2 because they are integers so we can not use this one
# Out:
# array([2, 1, 0, 2])

# %%
from sklearn.preprocessing import LabelBinarizer
obj = LabelBinarizer()
result = obj.fit_transform(result_category)

# %%
result
# Out:
# array([[0, 0, 1],
#        [0, 1, 0],
#        [1, 0, 0],
#        [0, 0, 1]])

# %%
obj.classes_
# Out:
# array(['Absent', 'Fail', 'Pass'], dtype='<U6')
