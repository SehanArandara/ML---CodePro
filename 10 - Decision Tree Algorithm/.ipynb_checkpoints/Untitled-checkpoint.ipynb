# %% [markdown]
# ## Decision Tree Algorithm

# %% [markdown]
# ![image.png](attachment:196911ab-e4cb-4c6d-8308-a776842ab80d.png)

# %% [markdown]
# - There are nodes - >  root node means high level node , leaf node means low level nodes
# - There are edges , branches
# - There are child and parent nodes also

# %% [markdown]
# - This is the how tree is working
#
# - ![image.png](attachment:31d4b61a-e7fe-4b93-abac-6fe6566469fc.png)

# %% [markdown]
# ![image.png](attachment:2b46c360-876d-4fab-8ad9-c8739c02b448.png)
#
# - Lets make a prediction
# - in here the rain = 0 and the temp = 31
# - so first we have to go rain = o branch and go the root node of the temp=31
# - so there will be two possibilies
# - one is play = 2/3 and not play = 1/3
# - so predicated value is 1 that is mean they will play
# -

# %% [markdown]
# - we can organize the tree as many way
# - if we select the Temperature first the Tree will change and if we select the rain first it will be another Tree
# - So there are some methods to select the features
# - ![image.png](attachment:9d902210-f9ae-4327-b044-efc38631f532.png)

# %% [markdown]
# - in here we are Entropy
# - we have to calculate the entropy like this
# - ![image.png](attachment:4c7d5e94-31d0-4c72-a344-1debbc094d85.png)

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('kyphosis.csv')
data.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
x =  data.iloc[:,1:4]
x.head()
# Out:
#    Age  Number  Start
# 0   71       3      5
# 1  158       3     14
# 2  128       4      5
# 3    2       5      1
# 4    1       4     15

# %%
y = data.iloc[:,0]
y.head()
# Out:
# 0     absent
# 1     absent
# 2    present
# 3     absent
# 4     absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.model_selection import train_test_split

x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (56, 3)

# %%
x_test.shape
# Out:
# (25, 3)

# %%
x.shape
# Out:
# (81, 3)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = model.predict(x_test)
pred[:5]
# Out:
# array(['absent', 'absent', 'absent', 'present', 'absent'], dtype=object)

# %%
y[:5]
# Out:
# 0     absent
# 1     absent
# 2    present
# 3     absent
# 4     absent
# Name: Kyphosis, dtype: object

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test,pred)
accuracy
# Out:
# 0.8

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test,pred)
cm
# Out:
# array([[19,  2],
#        [ 3,  1]], dtype=int64)

# %% [markdown]
# -- we can use the random foreset algorithm for more good
